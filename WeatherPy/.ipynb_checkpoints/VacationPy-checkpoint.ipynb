# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
#It is too bad that the .csv given for the cities, Geoapify doesn't have hotel records for.
#I spent all day yesterday and all day today trying to figure out what errors I was making throughout
#this challenge.
#The errors and lack of information is not a result of my work, yet the instructions and data
#didn't line up with the assignment. In addition, and unfortunately, the starter codes differ
#greatly from the the BCS module instructions. This caused us to consistently receive less credit
#for our work, guessing which one to follow while losing valuable time desparately in this BC.
#I still have many lessons to do to catch up and only have until tomorrow (now today) to finish.
#I'm not one to quit so I persist but when the material is totally foreign we rely on the instructions
#and guides. I would encourage those who are involved with the program to update the files, 
#sources, and instructions before the next class begins. My classmates have agreed and any one
#of us could give you examples.
#They may not have brought it up but after this frustration I don't mind being the squeaky wheel.
#Side note: In every class when in break out rooms and the TAs would drop in on our activity work,
#they were just as stumped.
#This challenge is probably one of the worst when it comes to accuracy and that's what we're trying
#to do with data...analyze it as accurately as possible.
#I'm going to take a stab at some more assignments today after work, but once the deadline is over,
#I would be happily lead you to some of the inaccuracies. (The same is copied in the last cell.)

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c54a7a8b-724d-4803-80b8-36730524e614'>
#   <div id="f54157f0-6ef5-486c-be6e-3144beead3e6" data-root-id="c54a7a8b-724d-4803-80b8-36730524e614" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities - Copy.csv")

# Display sample data
print(city_data_df)
#COLUMNS LABELED 1-8 WERE COMBINED IN THE "CITY" COLUMN. I CHOSE TO SPLIT OFF THE CITY NAME
#INTO ITS OWN COLUMN (USING 'CITIES - COPY.CSV')
# Out:
#      City.2  City.1            City        1         2      3    4    5     6  \
# 0         0       1         farsund  58.0948    6.8047  13.30  100    0  7.65
# 1         1       2     new norfolk -42.7826  147.0587  11.72   58   12  1.34
# 2         2       3       jamestown  42.0970  -79.2353   5.77   77  100  9.77
# 3         3       4         lanzhou  36.0564  103.7922  14.53   48   59  1.20
# 4         4       5         ushuaia -54.8000  -68.3000   8.81   81   75  3.09
# ..      ...     ...             ...      ...       ...    ...  ...  ...   ...
# 182     182     391  saint-francois  46.4154    3.9054  23.69   57    0  4.12
# 183     183     394         quesnel  52.9999 -122.5029   1.28   93    0  1.03
# 184     184     404  georgiyevskoye  58.7310   45.0240   5.97   93  100  2.17
# 185     185     475          nabire  -3.3667  135.4833  24.46   91  100  1.57
# 186     186     568       road town  18.4167  -64.6167  31.02   70   40  4.12
#
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map
map_plot = city_data_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = 'OSM',
    #tiles = "EsriImagery",
    frame_width = 600,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City",
    title = "City Humidity Map"
)
# Display the map plot
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lon,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
#NOWHERE IN OUR ACTIVITIES OR CLASSES DID I FIND HOW TO USE RANGES OR <> USING GEOAPIFY, PANDAS,
#AND HV PLOT. XPERT LEARNER IN BCS KEPT GIVING ME MISLEADING CODE AND KEPT REVERTING TO AIRPORTS
#(ONE OF OUR ACTIVITIES DURING MODULE 6) RATHER THAN HOTELS.
 

# Narrow down cities that fit criteria and drop any results with null values
#criteria_df = [#criteria_df(city_data_df)[
  #      "City",
   #     "Lon",
    #    "Lat",
     #   (Max Temp < 27),
      #  "Max Temp" > 21,
       # "Wind Speed" < 4.5,
        #"Cloudiness" == 0
#]
   ###### I HAVE TRIED EVERY COMBINATION TO NARROW DATA = SKIPPING ######     

        #weather_df[Max Temp] < 27,
        #weather_df[Max Temp] > 21,
        #weather_df[Wind Speed] < 4.5,
        #weather_df[Cloudiness] == 0

#criteria_pd = pd.DataFrame(criteria)
#ideal_weather_df = pd.criteria[criteria]
#ideal_weather_condition = max_temp_condition & wind_speed_condition & cloudiness_condition
###ideal_weather_df = weather_df[ideal_weather_condition]
#criteria_df

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lon', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = " "

# Display sample data
hotel_df.head(10)
# Out:
#            City Country      Lat       Lon  Humidity Hotel Name
# 0       farsund      PE -16.3658  -71.5004        62
# 1   new norfolk      PE -16.3776  -71.5206        62
# 2     jamestown      EG  30.7894   29.7758        82
# 3       lanzhou      PE -16.3775  -71.5200        62
# 4       ushuaia      EG  30.8066   29.7305        82
# 5        albany      PE -16.3670  -71.5066        62
# 6     carnarvon      PE -16.3676  -71.5075        62
# 7      sisimiut      PH  14.6573  120.9656        74
# 8  saint-pierre      PE -16.3663  -71.5032        62
# 9      colorado      PE -16.3759  -71.5228        62

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    City = row['City']
    Country = row['Country']
    Lon = row['Lon']
    Lat = row['Lat']
    Humidity = row['Humidity']
    
    params = {
        "categories": "hotel",
        "apiKey": geoapify_key,
        "limit": 10,
        "text": City  # This should be updated within the loop
}

    # Update the params for each city
    params["filter"] = f"circle:{Lon},{Lat},{radius}"
    params["bias"] = f"proximity:{Lon},{Lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address_json = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    if "features" in name_address_json and len(name_address_json["features"]) > 0:
        first_hotel = name_address_json["features"][0]
        hotel_df.loc[index, "Hotel Name"] = first_hotel["properties"]["name"]
    else:
        print(f"No hotel found for {City}, {Country}")
# Out:
# Starting hotel search
# No hotel found for farsund, PE
# No hotel found for new norfolk, PE
# No hotel found for jamestown, EG
# No hotel found for lanzhou, PE
# No hotel found for ushuaia, EG
# No hotel found for albany, PE
# No hotel found for carnarvon, PE
# No hotel found for sisimiut, PH
# No hotel found for saint-pierre, PE
# No hotel found for colorado, PE
# No hotel found for nikolskoye, EG
# No hotel found for trairi, PE
# No hotel found for dobryanka, PE
# No hotel found for qaanaaq, PE
# No hotel found for mataura, PE
# No hotel found for khatanga, PE
# No hotel found for tasiilaq, PE
# No hotel found for tiksi, PE
# No hotel found for puerto ayora, PE
# No hotel found for avarua, PE
# No hotel found for nuevo laredo, EG
# No hotel found for guiratinga, EG
# No hotel found for rikitea, EG
# No hotel found for dukat, PE
# No hotel found for constitucion, PE
# No hotel found for senneterre, EG
# No hotel found for bambous virieux, EG
# No hotel found for zangakatun, EG
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
map_plot = hotel_df.hvplot.points(
    'Lon', 
    'Lat',
    geo=True,
    tiles='OSM',
    size=100,
    color='blue',
    hover_cols=['City', 'Hotel Name', 'Country']
)
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lon,Lat]   (City,Hotel Name,Country)

# %%
#It is too bad that the .csv given for the cities, Geoapify doesn't have hotel records for.
#I spent all day yesterday and all day today trying to figure out what errors I was making.
#The errors and lack of information is not a result of my work, yet the instructions and data
#didn't line up with the assignment. In addition, and unfortunately, the starter codes differ
#greatly from the the BCS module instructions. This caused us to consistently receive less credit
#for our work, guessing which one to follow.
#I still have many lessons to do to catch up and only have until tomorrow (now today) to finish.
#I'm not one to quit so I persist but when the material is totally foreign we rely on the instructions
#and guides. I would encourage those who are involved with the program to update the files, 
#sources, and instructions before the next class begins. My classmates have agreed and any one
#of us could give you examples.
#They may not have brought it up but after this frustration I don't mind being the squeaky wheel.
#Side note: In every class when in break out rooms and the TAs would drop in on our activity work,
#they were just as stumped.
#This challenge is probably one of the worst when it comes to accuracy and that's what we're trying
#to do with data...analyze it as accurately as possible.
#I'm going to take a stab at some more assignments today after work, but once the deadline is over,
#I would be happily lead you to some of the inaccuracies. (The same is copied above.)
